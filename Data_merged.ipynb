# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import requests

# %% [markdown]
# ## DATA SET MERGED
#
# In this Jupyter Lab notebook, all necessary data from external datasets will be merged with the given dataset to support the analysis.

# %%
# Loading the original dataset 
data_folder ='/Users/mehdi/Documents/MA1/ADA2024/Data/'

# Headers 
column_names = ['Wiki_ID', 'Movie_ID', 'title','release_date', 'BoxOfficeRevenue', 'Runtime', 'Languages', 'Countries', 'Genres' ]

df = pd.read_csv(data_folder + 'movie.metadata.tsv', sep='\t', names=column_names, header=None)

# %%
df.head(2)
# Out:
#    Wiki_ID   Movie_ID                                              title  \
# 0   975900  /m/03vyhn                                     Ghosts of Mars
# 1  3196793  /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
#
#   release_date  BoxOfficeRevenue  Runtime                           Languages  \
# 0   2001-08-24        14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1   2000-02-16               NaN     95.0  {"/m/02h40lc": "English Language"}
#
#                                    Countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
#
#                                               Genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...

# %% [markdown]
# The values in the columns "Languages," "Countries," and "Genres" are structured as dictionaries—for example, `{"/m/02h40lc": "English Language"}`, where `"/m/02h40lc"` is the key and `"English Language"` is the value. To simplify future use of these values, they will be converted into lists of strings.

# %%
# Extract the values inside the second set of quotes for each key-value pair
def extract_values(_str):
    return re.findall(r': "([^"]+)"', _str)

# Apply the extraction function to the relevant columns
df['Languages'] = df['Languages'].apply(extract_values)
df['Countries'] = df['Countries'].apply(extract_values)
df['Genres'] = df['Genres'].apply(extract_values)

# Displaying the DataFrame to see the result
df.head(2)
# Out:
#    Wiki_ID   Movie_ID                                              title  \
# 0   975900  /m/03vyhn                                     Ghosts of Mars
# 1  3196793  /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
#
#   release_date  BoxOfficeRevenue  Runtime           Languages  \
# 0   2001-08-24        14010832.0     98.0  [English Language]
# 1   2000-02-16               NaN     95.0  [English Language]
#
#                     Countries  \
# 0  [United States of America]
# 1  [United States of America]
#
#                                               Genres
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]

# %% [markdown]
# # IMDb Datasets

# %% [markdown]
# The 'title.ratings.tsv' and 'title.akas.tsv' datasets come from the IMDb Non-Commercial Datasets, available at https://developer.imdb.com/non-commercial-datasets/.
#
# The 'title.ratings.tsv' file contains:
# - tconst (string): alphanumeric unique identifier of the title
# - averageRating: weighted average of all the individual user ratings
# - numVotes: number of votes the title has received
#
# and the 'title.akas.tsv' file contains:
#
# - titleId (string): a tconst, an alphanumeric unique identifier of the title
# - ordering (integer): a number to uniquely identify rows for a given titleId
# - title (string): the localized title
# - region (string):the region for this version of the title
# - language (string): the language of the title
# - types (array): Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning
# - attributes (array): Additional terms to describe this alternative title, not enumerated
# - isOriginalTitle (boolean): 0: not original title; 1: original title,
#
# These datasets must be merged to connect the 'title' with its corresponding 'averageRating' using the 'titleId'/'tconst'. Once merged, this data will be integrated into the initial dataset.
# IMDb rating data is essential for creating a metric called 'SuccessMetric,' which will be used to classify a movie's success.

# %%
#Load IMDb Datasets
data_folder = '/Users/mehdi/Documents/MA1/ADA2024/Data/'
df_rating = pd.read_csv(data_folder + 'title.ratings.tsv', sep='\t')
df_rating_title = pd.read_csv(data_folder + 'title.akas.tsv', sep='\t')

# %%
# Displaying the DataFrame
df_rating.head(2)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2096
# 1  tt0000002            5.6       282

# %%
#Displaying the DataFrame
df_rating_title.head(2)
# Out:
#      titleId  ordering       title region language     types     attributes  \
# 0  tt0000001         1  Carmencita     \N       \N  original             \N
# 1  tt0000001         2  Carmencita     DE       \N        \N  literal title
#
#    isOriginalTitle
# 0                1
# 1                0

# %%
df_rating = df_rating.rename(columns={'tconst': 'titleId'})
df_rating.head(2)
# Out:
#      titleId  averageRating  numVotes
# 0  tt0000001            5.7      2096
# 1  tt0000002            5.6       282

# %%
# Check if there are duplicate movies with the same title ID
# This ensures that each title ID is associated with only one movie entry
df_rating_title[df_rating_title['titleId']=='tt0228333']
# Out:
#            titleId  ordering                                  title region  \
# 1493874  tt0228333         1                         Ghosts of Mars     \N
# 1493875  tt0228333        10                         Ghosts of Mars     SE
# 1493876  tt0228333        11                         Ghosts of Mars     US
# 1493877  tt0228333        12                         Ghosts of Mars     ZA
# 1493878  tt0228333        13                     Fantasmas de Marte     BR
# 1493879  tt0228333        14                     Fantasmas de Marte     MX
# 1493880  tt0228333        15                     Fantasmas de Marte     PE
# 1493881  tt0228333        16                     Fantasmas de Marte     US
# 1493882  tt0228333        17                        A Mars szelleme     HU
# 1493883  tt0228333        18                        Apeili ston Ari     GR
# 1493884  tt0228333        19                   Bóng Ma Trên Sao Hỏa     VN
# 1493885  tt0228333         2                         Ghosts of Mars     AU
# 1493886  tt0228333        20                          Duchové Marsu     CZ
# 1493887  tt0228333        21                            Duchy Marsa     PL
# 1493888  tt0228333        22                           Duhovi Marsa     HR
# 1493889  tt0228333        23                     Fantasmas de marte     UY
# 1493890  tt0228333        24   Fantasmas de Marte de John Carpenter     ES
# 1493891  tt0228333        25  Fantasmas de Marte, de John Carpenter     PT
# 1493892  tt0228333        26                      Fantasmi da Marte     IT
# 1493893  tt0228333        27                  Fantomele de pe Marte     RO
# 1493894  tt0228333        28                      Fantômes sur Mars     CA
# 1493895  tt0228333        29        John Carpenter's Ghosts of Mars     US
# 1493896  tt0228333         3                         Ghosts of Mars     CA
# 1493897  tt0228333        30        John Carpenterin Ghosts of Mars     FI
# 1493898  tt0228333        31                           Marsi vaimud     EE
# 1493899  tt0228333        32                      Marso vaiduokliai     LT
# 1493900  tt0228333        33                   Strigoii de pe Marte     RO
# 1493901  tt0228333        34                        Απειλή στον Άρη     GR
# 1493902  tt0228333        35                        Духови са Марса     RS
# 1493903  tt0228333        36                          Привиди Марса     UA
# 1493904  tt0228333        37                         Призраки Марса     RU
# 1493905  tt0228333        38                       Призраци от Марс     BG
# 1493906  tt0228333        39                            ゴースト・オブ・マーズ     JP
# 1493907  tt0228333         4                         Ghosts of Mars     DE
# 1493908  tt0228333        40                                   火星異魔     TW
# 1493909  tt0228333         5                         Ghosts of Mars     DK
# 1493910  tt0228333         6                         Ghosts of Mars     EC
# 1493911  tt0228333         7                         Ghosts of Mars     FR
# 1493912  tt0228333         8                         Ghosts of Mars     GB
# 1493913  tt0228333         9                         Ghosts of Mars     IN
#
#         language        types                  attributes  isOriginalTitle
# 1493874       \N     original                          \N                1
# 1493875       \N  imdbDisplay                          \N                0
# 1493876       \N  imdbDisplay                          \N                0
# 1493877       en  imdbDisplay                          \N                0
# 1493878       \N           \N                          \N                0
# 1493879       \N           \N                          \N                0
# 1493880       \N  imdbDisplay                          \N                0
# 1493881       es  imdbDisplay                          \N                0
# 1493882       \N           \N                          \N                0
# 1493883       \N           \N        transliterated title                0
# 1493884       \N  imdbDisplay                          \N                0
# 1493885       \N  imdbDisplay                          \N                0
# 1493886       \N  imdbDisplay                          \N                0
# 1493887       \N  imdbDisplay                          \N                0
# 1493888       \N           \N                          \N                0
# 1493889       \N           \N  original subtitled version                0
# 1493890       \N  imdbDisplay                          \N                0
# 1493891       \N           \N                          \N                0
# 1493892       \N           \N                          \N                0
# 1493893       \N  alternative                          \N                0
# 1493894       fr           \N                          \N                0
# 1493895       \N           \N              complete title                0
# 1493896       en  imdbDisplay                          \N                0
# 1493897       \N           \N             video box title                0
# 1493898       \N  imdbDisplay                          \N                0
# 1493899       \N  imdbDisplay                          \N                0
# 1493900       \N  imdbDisplay                          \N                0
# 1493901       \N  imdbDisplay                          \N                0
# 1493902       \N  imdbDisplay                          \N                0
# 1493903       \N  imdbDisplay                          \N                0
# 1493904       \N  imdbDisplay                          \N                0
# 1493905       bg  imdbDisplay                          \N                0
# 1493906       ja  imdbDisplay                          \N                0
# 1493907       \N           \N                          \N                0
# 1493908       \N  imdbDisplay                          \N                0
# 1493909       \N  imdbDisplay                          \N                0
# 1493910       \N  imdbDisplay                          \N                0
# 1493911       \N           \N                          \N                0
# 1493912       \N  imdbDisplay                          \N                0
# 1493913       en  imdbDisplay                          \N                0

# %%
# For each title ID, keep only the original title.
df_rating_title=df_rating_title[df_rating_title['isOriginalTitle'] == 1.0]

# %%
# Count the occurrences of each unique value in the title 
value_count = df_rating_title['title'].value_counts()
print(value_count)
# Out:
# title
# Episode #1.1                   53140
# Episode #1.2                   47989
# Episode #1.3                   45430
# Episode #1.4                   42165
# Episode #1.5                   38656
#                                ...
# Astronomy in World Religion        1
# Does Hers Like Pumpkin?            1
# Sticking to the Script             1
# Slung Your Time                    1
# Horrid Henry Knows It All          1
# Name: count, Length: 5043401, dtype: int64

# %% [markdown]
# It seems that there are still duplicates...

# %%
# Count the occurrences of each unique value in the titleId
value_count1 = df_rating_title['titleId'].value_counts()
print(value_count1)
# Out:
# titleId
# tt3880980     2
# tt0000001     1
# tt31107355    1
# tt31107345    1
# tt31107346    1
#              ..
# tt15067248    1
# tt1506725     1
# tt15067252    1
# tt15067254    1
# tt9916880     1
# Name: count, Length: 11178939, dtype: int64

# %% [markdown]
# Apart from one movie, the duplicates appear to be based on the title rather than the title ID.
# This suggests that they could be different movies with the same title, rather than exact duplicates.
#
# Let's focus on observing the exception.

# %%
df_rating_title[df_rating_title['titleId'] == 'tt3880980']
# Out:
#             titleId  ordering  \
# 38672995  tt3880980         1
# 38672996  tt3880980         2
#
#                                                       title region language  \
# 38672995                                      Deadly Dreams     \N       \N
# 38672996  マックのハッスル刑事\tJP\tja\timdbDisplay\t\N\t0\ntt3880...     \N       \N
#
#              types attributes  isOriginalTitle
# 38672995  original         \N                1
# 38672996  original         \N                1

# %% [markdown]
# It seems to be the same movie in this case, but with different titles considered as each the original title.

# %%
#Merged title and rates
df_merged = pd.merge(df_rating, df_rating_title, on='titleId', how='inner')

# %%
df_merged
# Out:
#            titleId  averageRating  numVotes  ordering  \
# 0        tt0000001            5.7      2096         1
# 1        tt0000002            5.6       282         1
# 2        tt0000003            6.5      2114         1
# 3        tt0000004            5.4       182         1
# 4        tt0000005            6.2      2844         1
# ...            ...            ...       ...       ...
# 1492858  tt9916730            7.0        12         1
# 1492859  tt9916766            7.1        24         1
# 1492860  tt9916778            7.2        37         1
# 1492861  tt9916840            6.9        11         1
# 1492862  tt9916880            7.9         9         1
#
#                               title region language     types attributes  \
# 0                        Carmencita     \N       \N  original         \N
# 1            Le clown et ses chiens     \N       \N  original         \N
# 2                    Pauvre Pierrot     \N       \N  original         \N
# 3                       Un bon bock     \N       \N  original         \N
# 4                  Blacksmith Scene     \N       \N  original         \N
# ...                             ...    ...      ...       ...        ...
# 1492858                      6 Gunn     \N       \N  original         \N
# 1492859              Episode #10.15     \N       \N  original         \N
# 1492860                      Escape     \N       \N  original         \N
# 1492861  Horrid Henry's Comic Caper     \N       \N  original         \N
# 1492862   Horrid Henry Knows It All     \N       \N  original         \N
#
#          isOriginalTitle
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 1492858                1
# 1492859                1
# 1492860                1
# 1492861                1
# 1492862                1
#
# [1492863 rows x 10 columns]

# %%
value_count1 = df_merged['titleId'].value_counts()
print(value_count1)
# Out:
# titleId
# tt0000001     1
# tt2565978     1
# tt2565972     1
# tt2565964     1
# tt2565962     1
#              ..
# tt1055718     1
# tt1055717     1
# tt10557162    1
# tt1055716     1
# tt9916880     1
# Name: count, Length: 1492863, dtype: int64

# %% [markdown]
# There are no more duplicates based on the title ID. However, to differentiate between movies with the same title, additional information that varies between these movies is needed.
# The release year will be used for this purpose.
#
# To achieve this, the 'title.basics.tsv'file from the same IMDb webpage as before will be used to add the release year.
# The 'title.basics.tsv' file contains:
# - tconst (string): alphanumeric unique identifier of the title
# - titleType (string): the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - primaryTitle (string): the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - originalTitle (string): original title, in the original language
# - isAdult (boolean): 0: non-adult title; 1: adult title
# - startYear (YYYY): represents the release year of a title. In the case of TV Series, it is the series start year
# - endYear (YYYY): TV Series end year. '\N' for all other title types
# - runtimeMinutes: primary runtime of the title, in minutes
# - genres (string array): includes up to three genres associated with the title

# %%
# Load the new dataset
df_date = pd.read_csv(data_folder + 'title.basics.tsv', sep='\t')
# Out:
# C:\Users\mehdi\AppData\Local\Temp\ipykernel_28004\2084849319.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_date = pd.read_csv(data_folder + 'title.basics.tsv', sep='\t')

# %%
# Merged the two datasets
df_date = df_date.rename(columns={'tconst': 'titleId'})
df_merged_final = pd.merge(df_merged, df_date, on='titleId', how='inner')

# %%
# We have now the final dataset that is composed of two datasets that we got from IMDb 
# We used it in order to get the ratings of movies wich is crucial to later define the success of a movie
# The dataset that we now have is composed of : the titleID, the average rating on a scale of 1 to 10,
# the nimber of votes for the rating, the region, the language of the movie, the attributes, some informations on the movie title 
# like the length,type etc..., IsAdult (a bool that tells if the movie is an adult film), the release year, the runtime and the genre.
df_merged_final.head(2)
# Out:
#      titleId  averageRating  numVotes  ordering                   title  \
# 0  tt0000001            5.7      2096         1              Carmencita
# 1  tt0000002            5.6       282         1  Le clown et ses chiens
#
#   region language     types attributes  isOriginalTitle titleType  \
# 0     \N       \N  original         \N                1     short
# 1     \N       \N  original         \N                1     short
#
#              primaryTitle           originalTitle isAdult startYear endYear  \
# 0              Carmencita              Carmencita       0      1894      \N
# 1  Le clown et ses chiens  Le clown et ses chiens       0      1892      \N
#
#   runtimeMinutes             genres
# 0              1  Documentary,Short
# 1              5    Animation,Short

# %% [markdown]
# The final IMDb dataset will now be merged with the original dataset, utilizing the normalized title and release year to avoid any confusion.

# %%
df['Normalized_Title'] = df['title'].str.replace(" ", "").str.lower()
df_merged_final['Normalized_Title'] = df_merged_final['title'].str.replace(" ", "").str.lower()

# %%
df['releaseYear'] = df['release_date'].astype(str).str[:4]
df_merged_final['releaseYear'] = df_merged_final['startYear'].astype(str).str[:4]

# %%
df_merged_final['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvEpisode', 'tvSeries',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %% [markdown]
# Examining the 'titleType' category reveals entries labeled as 'videoGame' and 'tvSpecial'.
# Since these are not considered cinema categories, they will be removed from the dataset.

# %%
df_merged_final = df_merged_final[~df_merged_final['titleType'].isin(['videoGame', 'tvSpecial'])]

# %%
# Merged the original dataset with the treated IMDb dataset
df_IMDb = pd.merge(df, df_merged_final , on=['Normalized_Title', 'releaseYear'], how='inner')

# %%
# Check for duplicate titles
print(df_IMDb['title_x'].value_counts())
# Out:
# title_x
# Home                       23
# Love                       21
# Legacy                     19
# Macbeth                    18
# Alice in Wonderland        18
#                            ..
# Gangster Wars               1
# The Fall of a Nation        1
# Needhikku Thalaivanangu     1
# Free Ride                   1
# Another Nice Mess           1
# Name: count, Length: 43429, dtype: int64

# %%
#Verify for one duplicate title whether duplicates also exist for the release year.
df_IMDb[df_IMDb['title_x'] == 'Macbeth']
# Out:
#         Wiki_ID    Movie_ID  title_x release_date  BoxOfficeRevenue  Runtime  \
# 5234   16786364  /m/04062sb  Macbeth   1954-11-28               NaN    103.0
# 14910  15097368  /m/03hh969  Macbeth   1909-11-27               NaN     16.0
# 14911  15097368  /m/03hh969  Macbeth   1909-11-27               NaN     16.0
# 14912  15097255  /m/03hh92g  Macbeth   1909-12-03               NaN      NaN
# 14913  15097255  /m/03hh92g  Macbeth   1909-12-03               NaN      NaN
# 20326  15097470  /m/03hh99d  Macbeth         1913               NaN      NaN
# 20974   6652508   /m/0gg5jd  Macbeth   2006-09-21               NaN    109.0
# 20975   6652508   /m/0gg5jd  Macbeth   2006-09-21               NaN    109.0
# 20976   6652508   /m/0gg5jd  Macbeth   2006-09-21               NaN    109.0
# 24345   1966825   /m/069mfr  Macbeth   1948-10-01               NaN    107.0
# 31041    533378   /m/02mfrg  Macbeth   1971-10-13               NaN    141.0
# 32959  15097405  /m/03hh97b  Macbeth      1911-04               NaN     14.0
# 34712  23742116  /m/06zkbqs  Macbeth   1987-05-18               NaN    133.0
# 34713  23742116  /m/06zkbqs  Macbeth   1987-05-18               NaN    133.0
# 38335  13291774  /m/03c0sk5  Macbeth   1908-04-19               NaN      NaN
# 38632  16783663  /m/0405_81  Macbeth         1960               NaN    120.0
# 45814  15081705  /m/03hgwww  Macbeth         1916               NaN      NaN
# 47806  15097511  /m/03hh9c3  Macbeth   1915-12-31               NaN      NaN
#
#                              Languages  \
# 5234                [English Language]
# 14910               [Italian Language]
# 14911               [Italian Language]
# 14912                               []
# 14913                               []
# 20326                               []
# 20974               [English Language]
# 20975               [English Language]
# 20976               [English Language]
# 24345               [English Language]
# 31041               [English Language]
# 32959                    [Silent film]
# 34712               [Italian Language]
# 34713               [Italian Language]
# 38335  [Silent film, English Language]
# 38632                               []
# 45814                    [Silent film]
# 47806                [French Language]
#
#                                         Countries  \
# 5234   [United States of America, United Kingdom]
# 14910                                     [Italy]
# 14911                                     [Italy]
# 14912                                    [France]
# 14913                                    [France]
# 20326                                   [Germany]
# 20974                    [Australia, New Zealand]
# 20975                    [Australia, New Zealand]
# 20976                    [Australia, New Zealand]
# 24345                  [United States of America]
# 31041  [United States of America, United Kingdom]
# 32959                            [United Kingdom]
# 34712                           [France, Belgium]
# 34713                           [France, Belgium]
# 38335                  [United States of America]
# 38632                  [United States of America]
# 45814                  [United States of America]
# 47806                                    [France]
#
#                                                   Genres Normalized_Title  \
# 5234                                      [Comedy-drama]          macbeth
# 14910                          [Short Film, Silent film]          macbeth
# 14911                          [Short Film, Silent film]          macbeth
# 14912                                      [Silent film]          macbeth
# 14913                                      [Silent film]          macbeth
# 20326                               [Silent film, Indie]          macbeth
# 20974  [Crime Fiction, Thriller, Indie, World cinema,...          macbeth
# 20975  [Crime Fiction, Thriller, Indie, World cinema,...          macbeth
# 20976  [Crime Fiction, Thriller, Indie, World cinema,...          macbeth
# 24345                             [Costume drama, Drama]          macbeth
# 31041            [Costume drama, Drama, Film adaptation]          macbeth
# 32959            [Short Film, Silent film, Drama, Indie]          macbeth
# 34712                                            [Music]          macbeth
# 34713                                            [Music]          macbeth
# 38335  [Short Film, Silent film, Indie, Black-and-white]          macbeth
# 38632                                            [Drama]          macbeth
# 45814  [Silent film, Historical fiction, Drama, Black...          macbeth
# 47806                                      [Silent film]          macbeth
#
#        ... attributes isOriginalTitle  titleType  primaryTitle  originalTitle  \
# 5234   ...         \N               1    tvMovie       Macbeth        Macbeth
# 14910  ...         \N               1      short       Macbeth        Macbeth
# 14911  ...         \N               1      short       Macbeth        Macbeth
# 14912  ...         \N               1      short       Macbeth        Macbeth
# 14913  ...         \N               1      short       Macbeth        Macbeth
# 20326  ...         \N               1      movie       Macbeth        Macbeth
# 20974  ...         \N               1      movie       Macbeth        Macbeth
# 20975  ...         \N               1      movie       Macbeth        Macbeth
# 20976  ...         \N               1    tvMovie       Macbeth        Macbeth
# 24345  ...         \N               1      movie       Macbeth        Macbeth
# 31041  ...         \N               1    tvMovie       Macbeth        Macbeth
# 32959  ...         \N               1      short       Macbeth        Macbeth
# 34712  ...         \N               1      movie       Macbeth        Macbeth
# 34713  ...         \N               1      movie       Macbeth        Macbeth
# 38335  ...         \N               1      short       Macbeth        Macbeth
# 38632  ...         \N               1    tvMovie       Macbeth        Macbeth
# 45814  ...         \N               1      movie       Macbeth        Macbeth
# 47806  ...         \N               1      movie       Macbeth        Macbeth
#
#       isAdult startYear endYear runtimeMinutes               genres
# 5234        0      1954      \N            103                Drama
# 14910       0      1909      \N             \N          Drama,Short
# 14911       0      1909      \N             \N          Drama,Short
# 14912       0      1909      \N             \N          Drama,Short
# 14913       0      1909      \N             \N          Drama,Short
# 20326       0      1913      \N             50          Crime,Drama
# 20974       0      2006      \N            109  Crime,Drama,Fantasy
# 20975       0      2006      \N            118                Drama
# 20976       0      2006      \N            156                Music
# 24345       0      1948      \N            107    Drama,History,War
# 31041       0      1971      \N             60                Drama
# 32959       0      1911      \N             14          Drama,Short
# 34712       0      1987      \N            133                Music
# 34713       0      1987      \N             66          Crime,Drama
# 38335       0      1908      \N              9          Drama,Short
# 38632       0      1960      \N            108                Drama
# 45814       0      1916      \N             80        Drama,History
# 47806       0      1915      \N             55                   \N
#
# [18 rows x 29 columns]

# %% [markdown]
# Duplicate entries for year and title were observed, corresponding to different ratings, possibly from different webpages for the same movie. To address this, a weighted average will be calculated.

# %%
# Compute the average rating
df_IMDb['weighted_rating'] = df_IMDb['averageRating'] * df_IMDb['numVotes']

df_IMDb_f = df_IMDb.groupby(['Normalized_Title', 'releaseYear']).agg(
    Wiki_ID = ('Wiki_ID', 'first'),
    Movie_ID = ('Movie_ID', 'first'),
    title=('title_x', 'first'),  
    totRating=('weighted_rating', 'sum'),
    numVotes=('numVotes', 'sum'),
    release_date = ('release_date', 'first'),
    Runtime =  ('Runtime', 'first'),
    BoxOfficeRevenue = ('BoxOfficeRevenue', 'first'),
    Languages = ('Languages', 'first' ),
    Countries = ('Countries', 'first'),
    Genres=('Genres', 'first')

).reset_index()

df_IMDb_f['Rating'] = df_IMDb_f['totRating'] / df_IMDb_f['numVotes']

df_IMDb_f= df_IMDb_f.drop(columns=['totRating'])

# %%
df_IMDb_f.head(2)
# Out:
#     Normalized_Title releaseYear   Wiki_ID    Movie_ID                title  \
# 0  #1cheerleadercamp        2010  30332673  /m/0crs0hx  #1 Cheerleader Camp
# 1                  $        1971   4213160   /m/0bq8q8                    $
#
#    numVotes release_date  Runtime  BoxOfficeRevenue           Languages  \
# 0      3424         2010     90.0               NaN                  []
# 1      2948   1971-12-17    119.0               NaN  [English Language]
#
#                     Countries  \
# 0  [United States of America]
# 1  [United States of America]
#
#                                               Genres  Rating
# 0    [Sports, Sex comedy, Comedy film, Comedy, Teen]     3.7
# 1  [Crime Fiction, Heist, Action/Adventure, Thril...     6.3

# %%
# Save the DataFrame to a new CSV file
df_IMDb_f['year'] = df_IMDb_f['release_date'].astype(str).str[:4]
df_IMDb_f.to_csv('IMDb.csv', index=False)

# %%
df_IMDb_f.head(2)
# Out:
#     Normalized_Title releaseYear   Wiki_ID    Movie_ID                title  \
# 0  #1cheerleadercamp        2010  30332673  /m/0crs0hx  #1 Cheerleader Camp
# 1                  $        1971   4213160   /m/0bq8q8                    $
#
#    numVotes release_date  Runtime  BoxOfficeRevenue           Languages  \
# 0      3424         2010     90.0               NaN                  []
# 1      2948   1971-12-17    119.0               NaN  [English Language]
#
#                     Countries  \
# 0  [United States of America]
# 1  [United States of America]
#
#                                               Genres  Rating  year
# 0    [Sports, Sex comedy, Comedy film, Comedy, Teen]     3.7  2010
# 1  [Crime Fiction, Heist, Action/Adventure, Thril...     6.3  1971

# %% [markdown]
# # BechdelTest Dataset
#
# The 'df_bechdeltest' DataFrame is sourced from http://bechdeltest.com/api/v1/getAllMovies Web page, which provides data on movies rated based on the Bechdel Test.
#
# The Bechdel Test is a measure of the representation of women in films. A movie passes the test if it meets three criteria:
# 1. It features at least two named female characters,
# 2. who talk to each other,
# 3. about something other than a man.
#
# While passing the Bechdel Test doesn’t fully capture the complexity of female representation, it offers a useful baseline for understanding gender dynamics in cinema.
# This dataset will be used to observe whether the roles of women in films are significant and to analyze how this representation has evolved over the years.

# %%
url = 'http://bechdeltest.com/api/v1/getAllMovies'
# The data in this dataset is presented as such : 
# imdbid : the imdb id of the movie
# title
# rating : the result of the bechdel test, 1 if it has to have at least two [named] women in it, 2 if they talk to each other and 3 if it's about 
# something besides a man
# year : year of release of the movie
# id

response = requests.get(url)

if response.status_code == 200:
    print('Request was succesful')
    movie_data = response.json()
    df_bechdel = pd.DataFrame(movie_data)
    print(df_bechdel.sample())

else:
    print('Request failed')
# Out:
# Request was succesful
#      year    id   title   imdbid  rating
# 332  1934  4702  Maniac  0025465       3

# %%
df_bechdel.sample(2)
# Out:
#                  title  rating    id  year   imdbid
# 8419        Girls Lost       3  7832  2015  4425152
# 8948  Molly&#39;s Game       3  7948  2017  4209788

# %%
df_bechdel['Normalized_Title'] = df_bechdel['title'].str.replace(" ", "").str.lower()

# %%
df['year'] = df['release_date'].astype(str).str[:4]

# %%
df_bechdel['year'] = df_bechdel['year'].astype(str)

# %%
# Merge the original dataset with the Bechdel Test rating dataset 
df_bech_merged = pd.merge(df_bechdel,df , on=['Normalized_Title', 'year'], how='inner')

# %%
# Save the DataFrame to a new CSV file
df_bech_merged.to_csv('bechdeltest.csv', index=False)

# %% [markdown]
# The IMDb rating dataset is merged with the Bechdel Test dataset to combine information about movie ratings with data on gender representation in films.
#
# This allows for a more comprehensive analysis of both the quality of the movies and their portrayal of female characters, based on the Bechdel Test criteria.

# %%
df_imdb_bech = pd.read_csv(data_folder + 'IMDb.csv')

# %%
df_imdb_bech = df_imdb_bech.rename(columns={'Year': 'year'})
df_imdb_bech.head(2)
# Out:
#     Normalized_Title  releaseYear   Wiki_ID    Movie_ID                title  \
# 0  #1cheerleadercamp         2010  30332673  /m/0crs0hx  #1 Cheerleader Camp
# 1                  $         1971   4213160   /m/0bq8q8                    $
#
#    numVotes release_date  Runtime  BoxOfficeRevenue             Languages  \
# 0      3424         2010     90.0               NaN                    []
# 1      2948   1971-12-17    119.0               NaN  ['English Language']
#
#                       Countries  \
# 0  ['United States of America']
# 1  ['United States of America']
#
#                                               Genres  Rating  year
# 0  ['Sports', 'Sex comedy', 'Comedy film', 'Comed...     3.7  2010
# 1  ['Crime Fiction', 'Heist', 'Action/Adventure',...     6.3  1971

# %%
df_imdb_bech['year'] = df_imdb_bech['year'].astype(str)

# %%
# Merge the IMDb dataset with the Bechdel Test rating dataset 
df_bech_imdb_merged = pd.merge(df_bechdel,df_imdb_bech, on=['Normalized_Title', 'year'], how='inner')

# %%
# Rename and remove some columns to make the DataFrame clearer
df_bech_imdb_merged = df_bech_imdb_merged.rename(columns={'rating': 'ratingBechtest'})
df_bech_imdb_merged = df_bech_imdb_merged.loc[:, ~df_bech_imdb_merged.columns.str.endswith('_x')]
df_bech_imdb_merged.columns = df_bech_imdb_merged.columns.str.replace('_y$', '', regex=True)

# %%
# Save the DataFrame to a new CSV file
df_bech_imdb_merged.to_csv('whole_data.csv', index=False)

# %% [markdown]
# Mahdi's part

# %%
# In order to get the information on the budget of movie, we searched for a dataset online containing this information.
# We found on this website : https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset a dataset that might be a good fit 
# This dataset is a file called movies_metadata_TMDB.csv and its collumns contains information on 45,000 movies featured in the Full MovieLens dataset.
# Features include posters, backdrops, budget, revenue, release dates, languages, production countries and companies.
budget_data = pd.read_csv(data_folder+'movies_metadata_TMDB.csv')

# We can drop duplicates by Wiki_ID in our original dataset since it will bias the results
df= df.drop_duplicates(subset='Wiki_ID')

df.shape
# Out:
# C:\Users\mehdi\AppData\Local\Temp\ipykernel_28004\2301449931.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   budget_data = pd.read_csv(data_folder+'movies_metadata_TMDB.csv')
# (81741, 12)

# %%
# remove the lines where the budget is equal to 0
budget_data['budget'] = pd.to_numeric(budget_data['budget'], errors='coerce')
budget_data_clean = budget_data[budget_data['budget'].notna() & (budget_data['budget'] != 0)]

# removing the duplicates from this dataset also by the imdb_ID
budget_data_clean = budget_data_clean.drop_duplicates(subset='imdb_id')

budget_data_clean.head()
# Out:
#    adult                              belongs_to_collection      budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1  False                                                NaN  65000000.0
# 3  False                                                NaN  16000000.0
# 5  False                                                NaN  60000000.0
# 6  False                                                NaN  58000000.0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 3                                   NaN  31357  tt0114885                en
# 5                                   NaN    949  tt0113277                en
# 6                                   NaN  11860  tt0114319                en
#
#       original_title                                           overview  ...  \
# 0          Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1            Jumanji  When siblings Judy and Peter discover an encha...  ...
# 3  Waiting to Exhale  Cheated on, mistreated and stepped on, the wom...  ...
# 5               Heat  Obsessive master thief, Neil McCauley leads a ...  ...
# 6            Sabrina  An ugly duckling having undergone a remarkable...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 3   1995-12-22   81452156.0   127.0
# 5   1995-12-15  187436818.0   170.0
# 6   1995-12-15          0.0   127.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 6  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
#
#                                              tagline              title  \
# 0                                                NaN          Toy Story
# 1          Roll the dice and unleash the excitement!            Jumanji
# 3  Friends are the people who let you be yourself...  Waiting to Exhale
# 5                           A Los Angeles Crime Saga               Heat
# 6  You are cordially invited to the most surprisi...            Sabrina
#
#    video vote_average vote_count
# 0  False          7.7     5415.0
# 1  False          6.9     2413.0
# 3  False          6.1       34.0
# 5  False          7.7     1886.0
# 6  False          6.2      141.0
#
# [5 rows x 24 columns]

# %%
# We want first of all to ensure that the release_date column is in string format for both datasets
df['release_date'] = df['release_date'].astype(str)
budget_data_clean['release_date'] = budget_data_clean['release_date'].astype(str)

# Extracting the year part safely, cleaning it for the merge
df['year'] = df['release_date'].str[:4]
df['year'] = pd.to_numeric(df['Year'], errors='coerce').astype('Int64')

budget_data_clean['year'] = budget_data_clean['release_date'].str[:4]
budget_data_clean['year'] = pd.to_numeric(budget_data_clean['year'], errors='coerce').astype('Int64')

# %%
# now we want to merge the two data sets by the normalized title of the movie and the normalized release year, 
# then add the budget + vote_average to the movie dataset


df['Normalized_Title'] = df['title'].str.replace(" ", "").str.lower()
budget_data_clean['Normalized_Title'] = budget_data_clean['title'].str.replace(" ", "").str.lower()


merged_data_budget = df.merge(budget_data_clean[['Normalized_Title', 'year', 'budget','vote_average']], 
                              on=['Normalized_Title', 'year'], 
                              how='inner')


merged_data_budget.shape
# Out:
# (5832, 15)

# %%
# Now we use the IMDb dataset to get the ratings 
# since we also have ratings in the budget dataset, we take the mean of both of them 

df_IMDb_f.rename(columns={'BoxOfficeRevenue':'BoxOfficeRevenueImdb'}, inplace=True)
df_IMDb_f['year'] = df_IMDb_f['year'].astype(int)  # Example conversion



merged_data_imdb = merged_data_budget.merge(df_IMDb_f[['Normalized_Title','BoxOfficeRevenueImdb','Rating','year']],
                                            on=['Normalized_Title','year'], 
                                            how='inner')

merged_data_imdb.sample(5)
# Out:
#        Wiki_ID    Movie_ID             title release_date  BoxOfficeRevenue  \
# 4989  14237082  /m/03cyrcv      Black Legion         1937               NaN
# 4712   9334416  /m/0284_5f  West of Zanzibar         1928               NaN
# 1397  33217497  /m/0h7lvbd         Anonymous         2011               NaN
# 1827    168551   /m/016kmf  Murphy's Romance   1985-12-25        30762621.0
# 5026   1173339   /m/04ddm4          Jaws 3-D   1983-07-22        87987055.0
#
#       Runtime                        Languages                   Countries  \
# 4989     83.0               [English Language]  [United States of America]
# 4712     65.0  [Silent film, English Language]  [United States of America]
# 1397      4.0                               []                          []
# 1827    107.0               [English Language]  [United States of America]
# 5026     99.0               [English Language]  [United States of America]
#
#                                                  Genres Normalized_Title  \
# 4989  [Drama, Social problem film, Black-and-white, ...      blacklegion
# 4712                   [Horror, Drama, Black-and-white]   westofzanzibar
# 1397                                       [Short Film]        anonymous
# 1827            [Romantic comedy, Romance Film, Comedy]  murphy'sromance
# 5026  [Thriller, Natural horror films, Horror, Actio...          jaws3-d
#
#      releaseYear  year  Year      budget  vote_average  BoxOfficeRevenueImdb  \
# 4989        1937  1937  1937    235000.0           6.4                   NaN
# 4712        1928  1928  1928    259000.0           6.2                   NaN
# 1397        2011  2011  2011  30000000.0           6.3            15395087.0
# 1827        1985  1985  1985  13000000.0           5.7            30762621.0
# 5026        1983  1983  1983  20500000.0           4.2            87987055.0
#
#        Rating
# 4989  6.90000
# 4712  7.20000
# 1397  6.80017
# 1827  7.00000
# 5026  3.70000

# %%
# renaming 
merged_data_imdb_clean = merged_data_imdb

# now for all the lines where there is a value for BoxOfficeRevenueImdb and not for BoxOfficeRevenue we will copy the value from BoxOfficeRevenueImdb to BoxOfficeRevenue and vice versa
merged_data_imdb_clean['BoxOfficeRevenue'] = merged_data_imdb_clean['BoxOfficeRevenue'].fillna(merged_data_imdb_clean['BoxOfficeRevenueImdb'])
merged_data_imdb_clean['BoxOfficeRevenueImdb'] = merged_data_imdb_clean['BoxOfficeRevenueImdb'].fillna(merged_data_imdb_clean['BoxOfficeRevenue'])

# now for all the lines where there is a value for BoxOfficeRevenueImdb and for BoxOfficeRevenue we will calculate the difference in percentage between the two values and put it in a new column called BoxOfficeRevenueDifference
def percentage_difference(X, Y):                                           

    return np.abs((X-Y))/np.maximum(X,Y) * 100

merged_data_imdb_clean['BoxOfficeRevenueDifference'] = percentage_difference(merged_data_imdb_clean['BoxOfficeRevenue'], merged_data_imdb_clean['BoxOfficeRevenueImdb'])

# print the mean of the BoxOfficeRevenueDifference column
# we do this step to ensure that there is no big difference between the revenues in both datasets 

print(merged_data_imdb_clean['BoxOfficeRevenueDifference'].mean())


merged_data_imdb_clean.sample(5)
# Out:
# 0.027667015674755276
#        Wiki_ID    Movie_ID                title release_date  \
# 687    5159254   /m/0d5jxc       The Messengers   2007-02-02
# 103    7238588   /m/0kv1hy               Unholy         2007
# 4862  25673210  /m/09v50zp           The Keeper         2004
# 3460    607735   /m/02v_r6             Cocktail   1988-07-29
# 1593     28269    /m/07024  Saving Private Ryan   1998-07-24
#
#       BoxOfficeRevenue  Runtime  \
# 687                NaN     90.0
# 103                NaN     86.0
# 4862               NaN     96.0
# 3460       171504781.0    103.0
# 1593       481840909.0    169.0
#
#                                               Languages  \
# 687                                  [English Language]
# 103                                                  []
# 4862                                                 []
# 3460                                 [English Language]
# 1593  [French Language, Czech Language, German Langu...
#
#                                Countries  \
# 687   [United States of America, Canada]
# 103           [United States of America]
# 4862            [Canada, United Kingdom]
# 3460          [United States of America]
# 1593          [United States of America]
#
#                                                  Genres   Normalized_Title  \
# 687                           [Thriller, Drama, Horror]      themessengers
# 103   [Thriller, Science Fiction, Horror, Psychologi...             unholy
# 4862                 [Thriller, Psychological thriller]          thekeeper
# 3460  [Drama, Romantic drama, Romance Film, Buddy film]           cocktail
# 1593  [Ensemble Film, History, Drama, War film, Acti...  savingprivateryan
#
#      releaseYear  year  Year      budget  vote_average  BoxOfficeRevenueImdb  \
# 687         2007  2007  2007  16000000.0           5.6                   NaN
# 103         2007  2007  2007    250000.0           2.8                   NaN
# 4862        2004  2004  2004   4000000.0           5.3                   NaN
# 3460        1988  1988  1988  20000000.0           5.7           171504781.0
# 1593        1998  1998  1998  70000000.0           7.9           481840909.0
#
#       Rating  BoxOfficeRevenueDifference
# 687      5.3                         NaN
# 103      3.4                         NaN
# 4862     4.7                         NaN
# 3460     5.9                         0.0
# 1593     8.6                         0.0

# %%
# Removing again every duplicate line with the help of the Wiki_ID column
merged_data_imdb_clean = merged_data_imdb_clean.drop_duplicates(subset='Wiki_ID')


# adding a new column called Net_revenue that is  basically the difference between the BoxOfficeRevenue and the budget
merged_data_imdb_clean['Net_revenue'] = merged_data_imdb_clean['BoxOfficeRevenue'] - merged_data_imdb_clean['budget']


merged_data_imdb_clean.sample(5)
# Out:
# C:\Users\mehdi\AppData\Local\Temp\ipykernel_28004\1486757544.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_imdb_clean['Net_revenue'] = merged_data_imdb_clean['BoxOfficeRevenue'] - merged_data_imdb_clean['budget']
#        Wiki_ID    Movie_ID                          title release_date  \
# 3818   1367452   /m/04x4h9                    Jagged Edge   1985-09-05
# 1951   3146483   /m/08vf4y                The Glass House   2001-09-14
# 721     845738   /m/03gk0n                        Frantic   1988-02-26
# 2235    980601   /m/03wbkm                           Tape         2001
# 2058  20169617  /m/04yd0fv  Not Another Not Another Movie         2011
#
#       BoxOfficeRevenue  Runtime                            Languages  \
# 3818        40491165.0    109.0                   [English Language]
# 1951               NaN    111.0                   [English Language]
# 721         17637950.0    120.0  [French Language, English Language]
# 2235          490475.0     83.0                   [English Language]
# 2058               NaN     99.0                   [English Language]
#
#                                Countries  \
# 3818          [United States of America]
# 1951          [United States of America]
# 721   [France, United States of America]
# 2235          [United States of America]
# 2058          [United States of America]
#
#                                                  Genres  \
# 3818  [Crime Fiction, Thriller, Psychological thrill...
# 1951  [Thriller, Crime Fiction, Psychological thrill...
# 721   [Thriller, Mystery, Action, Psychological thri...
# 2235  [Crime Fiction, Drama, Psychological thriller,...
# 2058                     [Parody, Mockumentary, Comedy]
#
#                Normalized_Title releaseYear  year  Year      budget  \
# 3818                 jaggededge        1985  1985  1985  15000000.0
# 1951              theglasshouse        2001  2001  2001  30000000.0
# 721                     frantic        1988  1988  1988  20000000.0
# 2235                       tape        2001  2001  2001    100000.0
# 2058  notanothernotanothermovie        2011  2011  2011         4.0
#
#       vote_average  BoxOfficeRevenueImdb    Rating  \
# 3818           6.5            40491165.0  6.500000
# 1951           5.4                   NaN  5.812534
# 721            6.6            17637950.0  6.800000
# 2235           6.9              490475.0  7.200000
# 2058           2.8                   NaN  2.500000
#
#       BoxOfficeRevenueDifference  Net_revenue
# 3818                         0.0   25491165.0
# 1951                         NaN          NaN
# 721                          0.0   -2362050.0
# 2235                         0.0     390475.0
# 2058                         NaN          NaN

# %%
# Creating a new column 'pondered_rating' as the mean of 'Rating' and 'vote_average'
#merged_data_imdb_clean['pondered_rating'] = merged_data_imdb_clean[['Rating', 'vote_average']].mean(axis=1)

# removing a few useless columns for the final dataframe.
merged_data_imdb_clean.drop(columns=['vote_average', 'Rating'], inplace=True)
merged_data_imdb_clean.drop(columns=['BoxOfficeRevenueImdb', 'Normalized_Title', 'BoxOfficeRevenueDifference'], inplace=True)


merged_data_imdb_clean.to_csv('movie_data_successmetric_rating.csv', index=False)

# %%
merged_data_imdb_clean.sample(5)
# Out:
#        Wiki_ID    Movie_ID                       title release_date  \
# 1791   4777324   /m/0cmss_  Itty Bitty Titty Committee         2007
# 3097  34135810  /m/0hrdfny                     Captive   2012-02-12
# 4661  10193848  /m/02q4sd5                    Hideaway   1995-03-03
# 1636      4728    /m/01hq1              Batman Returns   1992-06-16
# 205    2352505   /m/075ym7                       Bones   2001-10-26
#
#       BoxOfficeRevenue  Runtime                             Languages  \
# 1791           33723.0     90.0                    [English Language]
# 3097               NaN    120.0  [Tagalog language, English Language]
# 4661        12201255.0    106.0                    [English Language]
# 1636       266822354.0    126.0                    [English Language]
# 205          7316658.0     96.0                    [English Language]
#
#                                            Countries  \
# 1791                      [United States of America]
# 3097  [France, Philippines, United Kingdom, Germany]
# 4661                      [United States of America]
# 1636      [United States of America, United Kingdom]
# 205               [United States of America, Canada]
#
#                                                  Genres releaseYear  year  \
# 1791  [LGBT, Gay Interest, Indie, Gay, Satire, Comed...        2007  2007
# 3097                                            [Drama]        2012  2012
# 4661  [Thriller, Horror, Supernatural, Psychological...        1995  1995
# 1636  [Crime Fiction, Thriller, Superhero movie, Mas...        1992  1992
# 205                    [Blaxploitation, Action, Horror]        2001  2001
#
#       Year      budget  Net_revenue
# 1791  2007   1000000.0    -966277.0
# 3097  2012     11180.0          NaN
# 4661  1995  15000000.0   -2798745.0
# 1636  1992  80000000.0  186822354.0
# 205   2001  10000000.0   -2683342.0
